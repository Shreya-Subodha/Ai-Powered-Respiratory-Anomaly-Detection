# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization,
                                     Reshape, Bidirectional, LSTM, Dropout, Dense)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.preprocessing import label_binarize

# ============ Parameters ============
IMG_SIZE = 256
BATCH_SIZE = 32
EPOCHS = 50
NUM_CLASSES = 3  # low, moderate, high

# ============ Data Loaders ============
train_gen = ImageDataGenerator(rescale=1./255)
val_gen = ImageDataGenerator(rescale=1./255)
test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    'train',  # folder with subfolders: low, moderate, high
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_data = val_gen.flow_from_directory(
    'validation',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_data = test_gen.flow_from_directory(
    'test',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Important for matching predictions to labels
)

# ============ Model Architecture (CNN-BiLSTM) ============
input_layer = Input(shape=(IMG_SIZE, IMG_SIZE, 3))

# CNN Feature Extractor
x = BatchNormalization()(input_layer)
x = Conv2D(64, (5, 7), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 3))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 3))(x)

x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)

# BiLSTM
x = Reshape((x.shape[1] * x.shape[2], x.shape[3]))(x)
x = Bidirectional(LSTM(256))(x)

# Dense Layers
x = Dropout(0.25)(x)
x = Dense(100, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)

# Build and Compile Model
model = Model(inputs=input_layer, outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

# ============ Training ============
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('cnn_bilstm_best.h5', save_best_only=True)
]

model.fit(train_data,
          validation_data=val_data,
          epochs=EPOCHS,
          callbacks=callbacks,
          verbose=2)

# Save Final Model
model.save("cnn_bilstm_final.h5")
print("Model saved as cnn_bilstm_final.h5")

# ============ Evaluate on Test Data ============
loss, acc = model.evaluate(test_data, verbose=2)
print(f"\nTest Accuracy: {acc*100:.2f}%, Test Loss: {loss:.4f}")

# ============ Predictions ============
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# ============ Confusion Matrix ============
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# ============ Classification Report ============
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ============ ROC Curve and AUC ============
# One-hot encode y_true
y_true_bin = label_binarize(y_true, classes=range(NUM_CLASSES))

# Compute ROC and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = roc_auc_score(y_true_bin[:, i], y_pred_probs[:, i])

# Plot ROC curves
plt.figure(figsize=(8, 6))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves by Class')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Found 720 images belonging to 3 classes.
# Found 90 images belonging to 3 classes.
# Found 90 images belonging to 3 classes.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  batch_normalization (BatchN  (None, 256, 256, 3)      12
#  ormalization)
#
#  conv2d (Conv2D)             (None, 256, 256, 64)      6784
#
#  max_pooling2d (MaxPooling2D  (None, 128, 85, 64)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 85, 64)       36928
#
#  conv2d_2 (Conv2D)           (None, 128, 85, 128)      73856
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 28, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 64, 28, 256)       295168
#
#  conv2d_4 (Conv2D)           (None, 64, 28, 128)       295040
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 14, 128)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 32, 14, 128)       147584
#
#  conv2d_6 (Conv2D)           (None, 32, 14, 128)       147584
#
#  reshape (Reshape)           (None, 448, 128)          0
#
#  bidirectional (Bidirectiona  (None, 512)              788480
#  l)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 100)               51300
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 1,843,039
# Trainable params: 1,843,033
# Non-trainable params: 6
# _________________________________________________________________
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 89
#      83 # ============ Training ============
#      84 callbacks = [
#      85     EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
#      86     ModelCheckpoint('cnn_bilstm_best.h5', save_best_only=True)
#      87 ]
# ---> 89 model.fit(train_data,
#      90           validation_data=val_data,
#      91           epochs=EPOCHS,
#      92           callbacks=callbacks,
#      93           verbose=2)
#      95 # Save Final Model
#      96 model.save("cnn_bilstm_final.h5")
#
# File c:\Users\pc_admin\anaconda3\envs\tf_gpu\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\pc_admin\anaconda3\envs\tf_gpu\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\pc_admin\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\pc_admin\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\pc_admin\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\pc_admin\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\pc_admin\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\pc_admin\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\pc_admin\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization,
                                     Reshape, LSTM, Dropout, Dense)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, f1_score
from sklearn.preprocessing import label_binarize

# ============ Parameters ============
IMG_SIZE = 256
BATCH_SIZE = 16
EPOCHS = 200
NUM_CLASSES = 3  # low, moderate, high

# ============ Data Loaders ============
train_gen = ImageDataGenerator(rescale=1./255)
val_gen = ImageDataGenerator(rescale=1./255)
test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    'train',  # folder with subfolders: low, moderate, high
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_data = val_gen.flow_from_directory(
    'validation',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_data = test_gen.flow_from_directory(
    'test',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Important for matching predictions to labels
)

# ============ Model Architecture (CNN-LSTM) ============
input_layer = Input(shape=(IMG_SIZE, IMG_SIZE, 3))

# CNN Feature Extractor
x = BatchNormalization()(input_layer)
x = Conv2D(64, (5, 7), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 3))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 3))(x)

x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)

# LSTM
x = Reshape((x.shape[1] * x.shape[2], x.shape[3]))(x)
x = LSTM(256)(x)

# Dense Layers
x = Dropout(0.25)(x)
x = Dense(100, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)

# Build and Compile Model
model = Model(inputs=input_layer, outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss='categorical_crossentropy',
              metrics=[
                  'accuracy',
                  tf.keras.metrics.Precision(name='precision'),
                  tf.keras.metrics.Recall(name='recall'),
                  tf.keras.metrics.AUC(name='auc')
              ])
model.summary()

# ============ Training ============
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('cnn_lstm_best.h5', save_best_only=True)
]

model.fit(train_data,
          validation_data=val_data,
          epochs=EPOCHS,
          callbacks=callbacks,
          verbose=2)

# Save Final Model
model.save("cnn_lstm_final.h5")
print("Model saved as cnn_lstm_final.h5")

# ============ Evaluate on Test Data ============
loss, acc, prec, rec, auc_score = model.evaluate(test_data, verbose=2)
print(f"\nTest Accuracy: {acc*100:.2f}%")
print(f"Test Loss: {loss:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall: {rec:.4f}")
print(f"AUC: {auc_score:.4f}")

# ============ Predictions ============
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# ============ Confusion Matrix ============
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# ============ Classification Report ============
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Macro-Averaged F1 Score
macro_f1 = f1_score(y_true, y_pred, average='macro')
print(f"Macro-Averaged F1 Score: {macro_f1:.4f}")

# ============ ROC Curve and AUC ============
y_true_bin = label_binarize(y_true, classes=range(NUM_CLASSES))
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = roc_auc_score(y_true_bin[:, i], y_pred_probs[:, i])

plt.figure(figsize=(8, 6))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves by Class')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Found 720 images belonging to 3 classes.
# Found 90 images belonging to 3 classes.
# Found 90 images belonging to 3 classes.
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  batch_normalization_2 (Batc  (None, 256, 256, 3)      12
#  hNormalization)
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 64)      6784
#
#  max_pooling2d_6 (MaxPooling  (None, 128, 85, 64)      0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 128, 85, 64)       36928
#
#  conv2d_16 (Conv2D)          (None, 128, 85, 128)      73856
#
#  max_pooling2d_7 (MaxPooling  (None, 64, 28, 128)      0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 64, 28, 256)       295168
#
#  conv2d_18 (Conv2D)          (None, 64, 28, 128)       295040
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 14, 128)      0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 32, 14, 128)       147584
#
#  conv2d_20 (Conv2D)          (None, 32, 14, 128)       147584
#
#  reshape_2 (Reshape)         (None, 448, 128)          0
#
#  lstm_2 (LSTM)               (None, 256)               394240
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 100)               25700
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_5 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 1,423,199
# Trainable params: 1,423,193
# Non-trainable params: 6
# _________________________________________________________________
# Epoch 1/200
# 45/45 - 5s - loss: 1.0927 - accuracy: 0.3528 - val_loss: 1.0986 - val_accuracy: 0.3333 - 5s/epoch - 118ms/step
# Epoch 2/200
# 45/45 - 4s - loss: 1.0302 - accuracy: 0.5069 - val_loss: 1.0953 - val_accuracy: 0.3444 - 4s/epoch - 91ms/step
# Epoch 3/200
# 45/45 - 4s - loss: 0.9310 - accuracy: 0.5208 - val_loss: 1.0297 - val_accuracy: 0.5111 - 4s/epoch - 90ms/step
# Epoch 4/200
# 45/45 - 4s - loss: 0.9024 - accuracy: 0.5653 - val_loss: 0.9373 - val_accuracy: 0.5556 - 4s/epoch - 90ms/step
# Epoch 5/200
# 45/45 - 4s - loss: 0.8829 - accuracy: 0.5667 - val_loss: 0.8954 - val_accuracy: 0.6333 - 4s/epoch - 90ms/step
# Epoch 6/200
# 45/45 - 4s - loss: 0.8944 - accuracy: 0.5722 - val_loss: 0.8740 - val_accuracy: 0.5778 - 4s/epoch - 90ms/step
# Epoch 7/200
# 45/45 - 4s - loss: 0.8591 - accuracy: 0.6014 - val_loss: 0.8664 - val_accuracy: 0.6778 - 4s/epoch - 90ms/step
# Epoch 8/200
# 45/45 - 4s - loss: 0.8499 - accuracy: 0.6028 - val_loss: 0.7988 - val_accuracy: 0.6222 - 4s/epoch - 90ms/step
# Epoch 9/200
# 45/45 - 4s - loss: 0.8589 - accuracy: 0.6000 - val_loss: 0.7555 - val_accuracy: 0.6667 - 4s/epoch - 91ms/step
# Epoch 10/200
# 45/45 - 4s - loss: 0.8240 - accuracy: 0.5958 - val_loss: 0.7849 - val_accuracy: 0.6222 - 4s/epoch - 89ms/step
# Epoch 11/200
# 45/45 - 4s - loss: 0.8246 - accuracy: 0.6167 - val_loss: 0.7777 - val_accuracy: 0.6889 - 4s/epoch - 90ms/step
# Epoch 12/200
# 45/45 - 4s - loss: 0.8276 - accuracy: 0.6097 - val_loss: 0.8073 - val_accuracy: 0.6333 - 4s/epoch - 90ms/step
# Epoch 13/200
# 45/45 - 4s - loss: 0.7884 - accuracy: 0.6167 - val_loss: 0.7398 - val_accuracy: 0.6556 - 4s/epoch - 91ms/step
# Epoch 14/200
# 45/45 - 4s - loss: 0.8166 - accuracy: 0.6153 - val_loss: 0.7541 - val_accuracy: 0.6778 - 4s/epoch - 91ms/step
# Epoch 15/200
# 45/45 - 4s - loss: 0.7929 - accuracy: 0.6278 - val_loss: 0.7512 - val_accuracy: 0.6778 - 4s/epoch - 90ms/step
# Epoch 16/200
# 45/45 - 4s - loss: 0.7848 - accuracy: 0.6278 - val_loss: 0.7306 - val_accuracy: 0.6889 - 4s/epoch - 91ms/step
# Epoch 17/200
# 45/45 - 4s - loss: 0.7813 - accuracy: 0.6208 - val_loss: 0.7280 - val_accuracy: 0.6778 - 4s/epoch - 92ms/step
# Epoch 18/200
# 45/45 - 4s - loss: 0.7785 - accuracy: 0.6417 - val_loss: 0.7274 - val_accuracy: 0.6778 - 4s/epoch - 92ms/step
# Epoch 19/200
# 45/45 - 4s - loss: 0.7617 - accuracy: 0.6556 - val_loss: 0.7205 - val_accuracy: 0.6778 - 4s/epoch - 94ms/step
# Epoch 20/200
# 45/45 - 4s - loss: 0.7122 - accuracy: 0.6764 - val_loss: 0.7156 - val_accuracy: 0.6889 - 4s/epoch - 93ms/step
# Epoch 21/200
# 45/45 - 4s - loss: 0.7220 - accuracy: 0.6583 - val_loss: 0.7106 - val_accuracy: 0.7111 - 4s/epoch - 92ms/step
# Epoch 22/200
# 45/45 - 4s - loss: 0.6876 - accuracy: 0.6819 - val_loss: 0.6839 - val_accuracy: 0.7333 - 4s/epoch - 92ms/step
# Epoch 23/200
# 45/45 - 4s - loss: 0.6796 - accuracy: 0.7014 - val_loss: 0.7000 - val_accuracy: 0.6667 - 4s/epoch - 90ms/step
# Epoch 24/200
# 45/45 - 4s - loss: 0.6965 - accuracy: 0.6958 - val_loss: 0.6609 - val_accuracy: 0.7333 - 4s/epoch - 91ms/step
# Epoch 25/200
# 45/45 - 4s - loss: 0.6297 - accuracy: 0.7250 - val_loss: 0.6391 - val_accuracy: 0.7444 - 4s/epoch - 92ms/step
# Epoch 26/200
# 45/45 - 4s - loss: 0.6713 - accuracy: 0.7167 - val_loss: 0.6956 - val_accuracy: 0.7111 - 4s/epoch - 90ms/step
# Epoch 27/200
# 45/45 - 4s - loss: 0.6353 - accuracy: 0.7250 - val_loss: 0.8561 - val_accuracy: 0.5889 - 4s/epoch - 91ms/step
# Epoch 28/200
# 45/45 - 4s - loss: 0.6308 - accuracy: 0.7236 - val_loss: 0.6213 - val_accuracy: 0.7111 - 4s/epoch - 94ms/step
# Epoch 29/200
# 45/45 - 4s - loss: 0.5682 - accuracy: 0.7542 - val_loss: 0.5718 - val_accuracy: 0.7667 - 4s/epoch - 93ms/step
# Epoch 30/200
# 45/45 - 4s - loss: 0.4910 - accuracy: 0.8014 - val_loss: 0.6621 - val_accuracy: 0.7667 - 4s/epoch - 92ms/step
# Epoch 31/200
# 45/45 - 4s - loss: 0.4668 - accuracy: 0.8139 - val_loss: 0.5293 - val_accuracy: 0.8000 - 4s/epoch - 93ms/step
# Epoch 32/200
# 45/45 - 4s - loss: 0.4845 - accuracy: 0.7792 - val_loss: 0.5271 - val_accuracy: 0.8000 - 4s/epoch - 93ms/step
# Epoch 33/200
# 45/45 - 4s - loss: 0.3958 - accuracy: 0.8458 - val_loss: 0.9399 - val_accuracy: 0.6667 - 4s/epoch - 93ms/step
# Epoch 34/200
# 45/45 - 4s - loss: 0.4020 - accuracy: 0.8375 - val_loss: 0.5068 - val_accuracy: 0.8000 - 4s/epoch - 94ms/step
# Epoch 35/200
# 45/45 - 4s - loss: 0.3180 - accuracy: 0.8722 - val_loss: 0.5053 - val_accuracy: 0.8222 - 4s/epoch - 94ms/step
# Epoch 36/200
# 45/45 - 4s - loss: 0.2912 - accuracy: 0.8778 - val_loss: 0.5034 - val_accuracy: 0.8333 - 4s/epoch - 95ms/step
# Epoch 37/200
# 45/45 - 4s - loss: 0.2192 - accuracy: 0.9181 - val_loss: 0.4589 - val_accuracy: 0.8556 - 4s/epoch - 94ms/step
# Epoch 38/200
# 45/45 - 4s - loss: 0.3763 - accuracy: 0.8472 - val_loss: 0.4511 - val_accuracy: 0.8333 - 4s/epoch - 95ms/step
# Epoch 39/200
# 45/45 - 4s - loss: 0.2008 - accuracy: 0.9347 - val_loss: 0.3779 - val_accuracy: 0.8778 - 4s/epoch - 93ms/step
# Epoch 40/200
# 45/45 - 4s - loss: 0.2268 - accuracy: 0.9139 - val_loss: 0.3187 - val_accuracy: 0.8889 - 4s/epoch - 93ms/step
# Epoch 41/200
# 45/45 - 4s - loss: 0.1596 - accuracy: 0.9431 - val_loss: 0.3337 - val_accuracy: 0.8667 - 4s/epoch - 92ms/step
# Epoch 42/200
# 45/45 - 4s - loss: 0.1233 - accuracy: 0.9556 - val_loss: 0.3878 - val_accuracy: 0.8778 - 4s/epoch - 93ms/step
# Epoch 43/200
# 45/45 - 4s - loss: 0.0952 - accuracy: 0.9722 - val_loss: 0.3996 - val_accuracy: 0.9000 - 4s/epoch - 90ms/step
# Epoch 44/200
# 45/45 - 4s - loss: 0.0667 - accuracy: 0.9819 - val_loss: 0.4992 - val_accuracy: 0.8667 - 4s/epoch - 91ms/step
# Epoch 45/200
# 45/45 - 4s - loss: 0.0340 - accuracy: 0.9944 - val_loss: 0.5700 - val_accuracy: 0.8778 - 4s/epoch - 91ms/step
# Model saved as cnn_lstm_final.h5
# 6/6 - 0s - loss: 0.4023 - accuracy: 0.8444 - 194ms/epoch - 32ms/step
#
# Test Accuracy: 84.44%, Test Loss: 0.4023
# 6/6 [==============================] - 0s 25ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.96      0.83      0.89        30
#          low       0.85      0.77      0.81        30
#     moderate       0.76      0.93      0.84        30
#
#     accuracy                           0.84        90
#    macro avg       0.86      0.84      0.85        90
# weighted avg       0.86      0.84      0.85        90

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization,
                                     Reshape, LSTM, Dropout, Dense)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, f1_score
from sklearn.preprocessing import label_binarize

# ============ Parameters ============
IMG_SIZE = 256
BATCH_SIZE = 8
EPOCHS = 200
NUM_CLASSES = 3  # low, moderate, high

# ============ Data Loaders ============
train_gen = ImageDataGenerator(rescale=1./255)
val_gen = ImageDataGenerator(rescale=1./255)
test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    'train',  # folder with subfolders: low, moderate, high
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_data = val_gen.flow_from_directory(
    'validation',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_data = test_gen.flow_from_directory(
    'test',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Important for matching predictions to labels
)

# ============ Model Architecture (CNN-LSTM) ============
input_layer = Input(shape=(IMG_SIZE, IMG_SIZE, 3))

# CNN Feature Extractor
x = BatchNormalization()(input_layer)
x = Conv2D(64, (5, 7), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 3))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 3))(x)

x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)

# LSTM
x = Reshape((x.shape[1] * x.shape[2], x.shape[3]))(x)

# LSTM layers
x = Bidirectional(512, return_sequences=True)(x)



x = Bidirectional(256, return_sequences=True)(x)
x = Bidirectional(128)(x)

# Dense Layers
x = Dropout(0.25)(x)
x = Dense(100, activation='relu')(x)
x = Dropout(0.75)(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)

# Build and Compile Model
model = Model(inputs=input_layer, outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss='categorical_crossentropy',
              metrics=[
                  'accuracy',
                  tf.keras.metrics.Precision(name='precision'),
                  tf.keras.metrics.Recall(name='recall'),
                  tf.keras.metrics.AUC(name='auc')
              ])
model.summary()

# ============ Training ============
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('cnn_lstm_best.h5', save_best_only=True)
]

model.fit(train_data,
          validation_data=val_data,
          epochs=EPOCHS,
          callbacks=callbacks,
          verbose=2)

# Save Final Model
model.save("cnn_lstm_final.h5")
print("Model saved as cnn_lstm_final.h5")

# ============ Evaluate on Test Data ============
loss, acc, prec, rec, auc_score = model.evaluate(test_data, verbose=2)
print(f"\nTest Accuracy: {acc*100:.2f}%")
print(f"Test Loss: {loss:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall: {rec:.4f}")
print(f"AUC: {auc_score:.4f}")

# ============ Predictions ============
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# ============ Confusion Matrix ============
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# ============ Classification Report ============
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Macro-Averaged F1 Score
macro_f1 = f1_score(y_true, y_pred, average='macro')
print(f"Macro-Averaged F1 Score: {macro_f1:.4f}")

# ============ ROC Curve and AUC ============
y_true_bin = label_binarize(y_true, classes=range(NUM_CLASSES))
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = roc_auc_score(y_true_bin[:, i], y_pred_probs[:, i])

plt.figure(figsize=(8, 6))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves by Class')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Found 720 images belonging to 3 classes.
# Found 90 images belonging to 3 classes.
# Found 90 images belonging to 3 classes.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  batch_normalization_1 (Batc  (None, 256, 256, 3)      12
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 64)      6784
#
#  max_pooling2d_3 (MaxPooling  (None, 128, 85, 64)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 128, 85, 64)       36928
#
#  conv2d_9 (Conv2D)           (None, 128, 85, 128)      73856
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 28, 128)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 64, 28, 256)       295168
#
#  conv2d_11 (Conv2D)          (None, 64, 28, 128)       295040
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 14, 128)      0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 32, 14, 128)       147584
#
#  conv2d_13 (Conv2D)          (None, 32, 14, 128)       147584
#
#  reshape_1 (Reshape)         (None, 448, 128)          0
#
#  lstm_3 (LSTM)               (None, 448, 512)          1312768
#
#  lstm_4 (LSTM)               (None, 448, 256)          787456
#
#  lstm_5 (LSTM)               (None, 128)               197120
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 100)               12900
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 3,313,503
# Trainable params: 3,313,497
# Non-trainable params: 6
# _________________________________________________________________
# Epoch 1/200
# 90/90 - 14s - loss: 1.0933 - accuracy: 0.3486 - precision: 0.5000 - recall: 0.0028 - auc: 0.5281 - val_loss: 1.0969 - val_accuracy: 0.3333 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5440 - 14s/epoch - 158ms/step
# Epoch 2/200
# 90/90 - 8s - loss: 1.0207 - accuracy: 0.4597 - precision: 0.5473 - recall: 0.1528 - auc: 0.6718 - val_loss: 0.9373 - val_accuracy: 0.6111 - val_precision: 0.7895 - val_recall: 0.1667 - val_auc: 0.7904 - 8s/epoch - 94ms/step
# Epoch 3/200
# 90/90 - 8s - loss: 0.9517 - accuracy: 0.4931 - precision: 0.6144 - recall: 0.2611 - auc: 0.7202 - val_loss: 0.9450 - val_accuracy: 0.5667 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7807 - 8s/epoch - 94ms/step
# Epoch 4/200
# 90/90 - 9s - loss: 0.9423 - accuracy: 0.5347 - precision: 0.5913 - recall: 0.3194 - auc: 0.7393 - val_loss: 0.8346 - val_accuracy: 0.6000 - val_precision: 0.7015 - val_recall: 0.5222 - val_auc: 0.8139 - 9s/epoch - 95ms/step
# Epoch 5/200
# 90/90 - 9s - loss: 0.8904 - accuracy: 0.5833 - precision: 0.6202 - recall: 0.3833 - auc: 0.7666 - val_loss: 0.8357 - val_accuracy: 0.5889 - val_precision: 0.7500 - val_recall: 0.4000 - val_auc: 0.8084 - 9s/epoch - 96ms/step
# Epoch 6/200
# 90/90 - 9s - loss: 0.9007 - accuracy: 0.5694 - precision: 0.6121 - recall: 0.3639 - auc: 0.7562 - val_loss: 0.8487 - val_accuracy: 0.6222 - val_precision: 0.6875 - val_recall: 0.4889 - val_auc: 0.8171 - 9s/epoch - 97ms/step
# Epoch 7/200
# 90/90 - 9s - loss: 0.9010 - accuracy: 0.5569 - precision: 0.6442 - recall: 0.3847 - auc: 0.7611 - val_loss: 0.7981 - val_accuracy: 0.6000 - val_precision: 0.7059 - val_recall: 0.5333 - val_auc: 0.8306 - 9s/epoch - 98ms/step
# Epoch 8/200
# 90/90 - 9s - loss: 0.8817 - accuracy: 0.5833 - precision: 0.6102 - recall: 0.3806 - auc: 0.7666 - val_loss: 0.8334 - val_accuracy: 0.5889 - val_precision: 0.6620 - val_recall: 0.5222 - val_auc: 0.8072 - 9s/epoch - 98ms/step
# Epoch 9/200
# 90/90 - 9s - loss: 0.8662 - accuracy: 0.5722 - precision: 0.6599 - recall: 0.4069 - auc: 0.7745 - val_loss: 0.7727 - val_accuracy: 0.6222 - val_precision: 0.7000 - val_recall: 0.5444 - val_auc: 0.8456 - 9s/epoch - 98ms/step
# Epoch 10/200
# 90/90 - 9s - loss: 0.8332 - accuracy: 0.6056 - precision: 0.6558 - recall: 0.4736 - auc: 0.7947 - val_loss: 0.7818 - val_accuracy: 0.6444 - val_precision: 0.7049 - val_recall: 0.4778 - val_auc: 0.8439 - 9s/epoch - 97ms/step
# Epoch 11/200
# 90/90 - 9s - loss: 0.8214 - accuracy: 0.5903 - precision: 0.6486 - recall: 0.4333 - auc: 0.7943 - val_loss: 0.7512 - val_accuracy: 0.6222 - val_precision: 0.6883 - val_recall: 0.5889 - val_auc: 0.8402 - 9s/epoch - 99ms/step
# Epoch 12/200
# 90/90 - 9s - loss: 0.8077 - accuracy: 0.6181 - precision: 0.6630 - recall: 0.5056 - auc: 0.8057 - val_loss: 0.7443 - val_accuracy: 0.6444 - val_precision: 0.6711 - val_recall: 0.5667 - val_auc: 0.8518 - 9s/epoch - 100ms/step
# Epoch 13/200
# 90/90 - 9s - loss: 0.7836 - accuracy: 0.5958 - precision: 0.6434 - recall: 0.4986 - auc: 0.8119 - val_loss: 0.6944 - val_accuracy: 0.6667 - val_precision: 0.6974 - val_recall: 0.5889 - val_auc: 0.8661 - 9s/epoch - 98ms/step
# Epoch 14/200
# 90/90 - 9s - loss: 0.7251 - accuracy: 0.6444 - precision: 0.7109 - recall: 0.5361 - auc: 0.8481 - val_loss: 0.6429 - val_accuracy: 0.7333 - val_precision: 0.7468 - val_recall: 0.6556 - val_auc: 0.8872 - 9s/epoch - 100ms/step
# Epoch 15/200
# 90/90 - 9s - loss: 0.7124 - accuracy: 0.6556 - precision: 0.6975 - recall: 0.5347 - auc: 0.8529 - val_loss: 0.6317 - val_accuracy: 0.7111 - val_precision: 0.7826 - val_recall: 0.6000 - val_auc: 0.8981 - 9s/epoch - 99ms/step
# Epoch 16/200
# 90/90 - 9s - loss: 0.6617 - accuracy: 0.6986 - precision: 0.7341 - recall: 0.6097 - auc: 0.8766 - val_loss: 0.6165 - val_accuracy: 0.6889 - val_precision: 0.7126 - val_recall: 0.6889 - val_auc: 0.8920 - 9s/epoch - 100ms/step
# Epoch 17/200
# 90/90 - 9s - loss: 0.6459 - accuracy: 0.7236 - precision: 0.7369 - recall: 0.6264 - auc: 0.8814 - val_loss: 0.6908 - val_accuracy: 0.6667 - val_precision: 0.7037 - val_recall: 0.6333 - val_auc: 0.8625 - 9s/epoch - 98ms/step
# Epoch 18/200
# 90/90 - 9s - loss: 0.6317 - accuracy: 0.7486 - precision: 0.7787 - recall: 0.6694 - auc: 0.8881 - val_loss: 0.7601 - val_accuracy: 0.6444 - val_precision: 0.6795 - val_recall: 0.5889 - val_auc: 0.8464 - 9s/epoch - 99ms/step
# Epoch 19/200
# 90/90 - 9s - loss: 0.5922 - accuracy: 0.7347 - precision: 0.7708 - recall: 0.6819 - auc: 0.8996 - val_loss: 0.6297 - val_accuracy: 0.7111 - val_precision: 0.7356 - val_recall: 0.7111 - val_auc: 0.8848 - 9s/epoch - 97ms/step
# Epoch 20/200
# 90/90 - 9s - loss: 0.5891 - accuracy: 0.7403 - precision: 0.7640 - recall: 0.6653 - auc: 0.8995 - val_loss: 0.5589 - val_accuracy: 0.7444 - val_precision: 0.7647 - val_recall: 0.7222 - val_auc: 0.9169 - 9s/epoch - 98ms/step
# Epoch 21/200
# 90/90 - 9s - loss: 0.5674 - accuracy: 0.7597 - precision: 0.7866 - recall: 0.7167 - auc: 0.9071 - val_loss: 0.5995 - val_accuracy: 0.7111 - val_precision: 0.7093 - val_recall: 0.6778 - val_auc: 0.9055 - 9s/epoch - 97ms/step
# Epoch 22/200
# 90/90 - 9s - loss: 0.5310 - accuracy: 0.7889 - precision: 0.8077 - recall: 0.7292 - auc: 0.9223 - val_loss: 0.5806 - val_accuracy: 0.7111 - val_precision: 0.7143 - val_recall: 0.6667 - val_auc: 0.9100 - 9s/epoch - 97ms/step
# Epoch 23/200
# 90/90 - 9s - loss: 0.5176 - accuracy: 0.7986 - precision: 0.8149 - recall: 0.7583 - auc: 0.9269 - val_loss: 0.5358 - val_accuracy: 0.7556 - val_precision: 0.7674 - val_recall: 0.7333 - val_auc: 0.9223 - 9s/epoch - 97ms/step
# Epoch 24/200
# 90/90 - 9s - loss: 0.4614 - accuracy: 0.8250 - precision: 0.8465 - recall: 0.7889 - auc: 0.9442 - val_loss: 0.6387 - val_accuracy: 0.7333 - val_precision: 0.7500 - val_recall: 0.7333 - val_auc: 0.9018 - 9s/epoch - 97ms/step
# Epoch 25/200
# 90/90 - 9s - loss: 0.4790 - accuracy: 0.7972 - precision: 0.8185 - recall: 0.7639 - auc: 0.9354 - val_loss: 0.4924 - val_accuracy: 0.8111 - val_precision: 0.8046 - val_recall: 0.7778 - val_auc: 0.9343 - 9s/epoch - 97ms/step
# Epoch 26/200
# 90/90 - 9s - loss: 0.4289 - accuracy: 0.8306 - precision: 0.8453 - recall: 0.8042 - auc: 0.9502 - val_loss: 0.5675 - val_accuracy: 0.7778 - val_precision: 0.7791 - val_recall: 0.7444 - val_auc: 0.9223 - 9s/epoch - 95ms/step
# Epoch 27/200
# 90/90 - 9s - loss: 0.3841 - accuracy: 0.8542 - precision: 0.8612 - recall: 0.8361 - auc: 0.9582 - val_loss: 0.4635 - val_accuracy: 0.8556 - val_precision: 0.8636 - val_recall: 0.8444 - val_auc: 0.9472 - 9s/epoch - 96ms/step
# Epoch 28/200
# 90/90 - 9s - loss: 0.2935 - accuracy: 0.8931 - precision: 0.9050 - recall: 0.8861 - auc: 0.9756 - val_loss: 0.6217 - val_accuracy: 0.7444 - val_precision: 0.7586 - val_recall: 0.7333 - val_auc: 0.9170 - 9s/epoch - 96ms/step
# Epoch 29/200
# 90/90 - 9s - loss: 0.3104 - accuracy: 0.8875 - precision: 0.8962 - recall: 0.8750 - auc: 0.9732 - val_loss: 0.4295 - val_accuracy: 0.8444 - val_precision: 0.8427 - val_recall: 0.8333 - val_auc: 0.9582 - 9s/epoch - 98ms/step
# Epoch 30/200
# 90/90 - 9s - loss: 0.2809 - accuracy: 0.9083 - precision: 0.9173 - recall: 0.8931 - auc: 0.9774 - val_loss: 0.3602 - val_accuracy: 0.8889 - val_precision: 0.8966 - val_recall: 0.8667 - val_auc: 0.9655 - 9s/epoch - 97ms/step
# Epoch 31/200
# 90/90 - 9s - loss: 0.2248 - accuracy: 0.9306 - precision: 0.9364 - recall: 0.9208 - auc: 0.9857 - val_loss: 0.6498 - val_accuracy: 0.7778 - val_precision: 0.7753 - val_recall: 0.7667 - val_auc: 0.9251 - 9s/epoch - 96ms/step
# Epoch 32/200
# 90/90 - 9s - loss: 0.1821 - accuracy: 0.9542 - precision: 0.9580 - recall: 0.9514 - auc: 0.9893 - val_loss: 0.4045 - val_accuracy: 0.8556 - val_precision: 0.8652 - val_recall: 0.8556 - val_auc: 0.9565 - 9s/epoch - 96ms/step
# Epoch 33/200
# 90/90 - 9s - loss: 0.2130 - accuracy: 0.9264 - precision: 0.9348 - recall: 0.9167 - auc: 0.9866 - val_loss: 0.2798 - val_accuracy: 0.9333 - val_precision: 0.9333 - val_recall: 0.9333 - val_auc: 0.9744 - 9s/epoch - 97ms/step
# Epoch 34/200
# 90/90 - 9s - loss: 0.2119 - accuracy: 0.9361 - precision: 0.9373 - recall: 0.9347 - auc: 0.9858 - val_loss: 0.4530 - val_accuracy: 0.8444 - val_precision: 0.8506 - val_recall: 0.8222 - val_auc: 0.9571 - 9s/epoch - 96ms/step
# Epoch 35/200
# 90/90 - 9s - loss: 0.1095 - accuracy: 0.9667 - precision: 0.9732 - recall: 0.9597 - auc: 0.9977 - val_loss: 0.2619 - val_accuracy: 0.9444 - val_precision: 0.9444 - val_recall: 0.9444 - val_auc: 0.9792 - 9s/epoch - 96ms/step
# Epoch 36/200
# 90/90 - 9s - loss: 0.0489 - accuracy: 0.9875 - precision: 0.9916 - recall: 0.9875 - auc: 0.9996 - val_loss: 0.5000 - val_accuracy: 0.8778 - val_precision: 0.8876 - val_recall: 0.8778 - val_auc: 0.9607 - 9s/epoch - 95ms/step
# Epoch 37/200
# 90/90 - 9s - loss: 0.2411 - accuracy: 0.9292 - precision: 0.9363 - recall: 0.9181 - auc: 0.9808 - val_loss: 0.2540 - val_accuracy: 0.9333 - val_precision: 0.9333 - val_recall: 0.9333 - val_auc: 0.9828 - 9s/epoch - 96ms/step
# Epoch 38/200
# 90/90 - 9s - loss: 0.1115 - accuracy: 0.9722 - precision: 0.9776 - recall: 0.9694 - auc: 0.9935 - val_loss: 0.4613 - val_accuracy: 0.8556 - val_precision: 0.8736 - val_recall: 0.8444 - val_auc: 0.9587 - 9s/epoch - 95ms/step
# Epoch 39/200
# 90/90 - 9s - loss: 0.1200 - accuracy: 0.9625 - precision: 0.9691 - recall: 0.9569 - auc: 0.9964 - val_loss: 0.2889 - val_accuracy: 0.9444 - val_precision: 0.9444 - val_recall: 0.9444 - val_auc: 0.9785 - 9s/epoch - 95ms/step
# Epoch 40/200
# 90/90 - 9s - loss: 0.0387 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9997 - val_loss: 0.5655 - val_accuracy: 0.8222 - val_precision: 0.8222 - val_recall: 0.8222 - val_auc: 0.9594 - 9s/epoch - 95ms/step
# Epoch 41/200
# 90/90 - 9s - loss: 0.1663 - accuracy: 0.9403 - precision: 0.9479 - recall: 0.9347 - auc: 0.9906 - val_loss: 0.2470 - val_accuracy: 0.9333 - val_precision: 0.9333 - val_recall: 0.9333 - val_auc: 0.9837 - 9s/epoch - 96ms/step
# Epoch 42/200
# 90/90 - 9s - loss: 0.0189 - accuracy: 0.9986 - precision: 0.9986 - recall: 0.9986 - auc: 1.0000 - val_loss: 0.2886 - val_accuracy: 0.9444 - val_precision: 0.9444 - val_recall: 0.9444 - val_auc: 0.9814 - 9s/epoch - 96ms/step
# Epoch 43/200
# 90/90 - 9s - loss: 0.0140 - accuracy: 0.9972 - precision: 0.9972 - recall: 0.9972 - auc: 1.0000 - val_loss: 0.3586 - val_accuracy: 0.9222 - val_precision: 0.9222 - val_recall: 0.9222 - val_auc: 0.9736 - 9s/epoch - 96ms/step
# Epoch 44/200
# 90/90 - 9s - loss: 0.0144 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.2984 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9814 - 9s/epoch - 96ms/step
# Epoch 45/200
# 90/90 - 9s - loss: 0.0074 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.3063 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9765 - 9s/epoch - 97ms/step
# Epoch 46/200
# 90/90 - 9s - loss: 0.0090 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.3315 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9723 - 9s/epoch - 97ms/step
# Model saved as cnn_lstm_final.h5
# 12/12 - 0s - loss: 0.4744 - accuracy: 0.8667 - precision: 0.8652 - recall: 0.8556 - auc: 0.9603 - 431ms/epoch - 36ms/step
#
# Test Accuracy: 86.67%
# Test Loss: 0.4744
# Precision: 0.8652
# Recall: 0.8556
# AUC: 0.9603
# 12/12 [==============================] - 1s 33ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.77      0.90      0.83        30
#          low       0.88      0.77      0.82        30
#     moderate       0.97      0.93      0.95        30
#
#     accuracy                           0.87        90
#    macro avg       0.87      0.87      0.87        90
# weighted avg       0.87      0.87      0.87        90
#
# Macro-Averaged F1 Score: 0.8671

# %%
# Bidirectional LSTM
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization,
                                     Reshape, LSTM, Dropout, Dense)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, f1_score
from sklearn.preprocessing import label_binarize
from tensorflow.keras.layers import Bidirectional


# ============ Parameters ============
IMG_SIZE = 256
BATCH_SIZE = 8
EPOCHS = 200
NUM_CLASSES = 3  # low, moderate, high

# ============ Data Loaders ============
train_gen = ImageDataGenerator(rescale=1./255)
val_gen = ImageDataGenerator(rescale=1./255)
test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    'train',  # folder with subfolders: low, moderate, high
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_data = val_gen.flow_from_directory(
    'validation',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_data = test_gen.flow_from_directory(
    'test',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Important for matching predictions to labels
)

# ============ Model Architecture (CNN-LSTM) ============
input_layer = Input(shape=(IMG_SIZE, IMG_SIZE, 3))

# CNN Feature Extractor
x = BatchNormalization()(input_layer)
x = Conv2D(64, (5, 7), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 3))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 3))(x)

x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)

# LSTM
x = Reshape((x.shape[1] * x.shape[2], x.shape[3]))(x)

# LSTM layers
x = Bidirectional(LSTM(512, return_sequences=True))(x)
x = Bidirectional(LSTM(256, return_sequences=True))(x)
x = Bidirectional(LSTM(128))(x)

# Dense Layers
x = Dropout(0.25)(x)
x = Dense(100, activation='relu')(x)
x = Dropout(0.75)(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)

# Build and Compile Model
model = Model(inputs=input_layer, outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss='categorical_crossentropy',
              metrics=[
                  'accuracy',
                  tf.keras.metrics.Precision(name='precision'),
                  tf.keras.metrics.Recall(name='recall'),
                  tf.keras.metrics.AUC(name='auc')
              ])
model.summary()

# ============ Training ============
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('cnn_lstm_best.h5', save_best_only=True)
]

model.fit(train_data,
          validation_data=val_data,
          epochs=EPOCHS,
          callbacks=callbacks,
          verbose=2)

# Save Final Model
model.save("cnn_lstm_final.h5")
print("Model saved as cnn_lstm_final.h5")

# ============ Evaluate on Test Data ============
loss, acc, prec, rec, auc_score = model.evaluate(test_data, verbose=2)
print(f"\nTest Accuracy: {acc*100:.2f}%")
print(f"Test Loss: {loss:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall: {rec:.4f}")
print(f"AUC: {auc_score:.4f}")

# ============ Predictions ============
y_pred_probs = model.predict(test_data)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_data.classes
class_labels = list(test_data.class_indices.keys())

# ============ Confusion Matrix ============
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

# ============ Classification Report ============
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Macro-Averaged F1 Score
macro_f1 = f1_score(y_true, y_pred, average='macro')
print(f"Macro-Averaged F1 Score: {macro_f1:.4f}")

# ============ ROC Curve and AUC ============
y_true_bin = label_binarize(y_true, classes=range(NUM_CLASSES))
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = roc_auc_score(y_true_bin[:, i], y_pred_probs[:, i])

plt.figure(figsize=(8, 6))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves by Class')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Found 720 images belonging to 3 classes.
# Found 90 images belonging to 3 classes.
# Found 90 images belonging to 3 classes.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  batch_normalization (BatchN  (None, 256, 256, 3)      12
#  ormalization)
#
#  conv2d (Conv2D)             (None, 256, 256, 64)      6784
#
#  max_pooling2d (MaxPooling2D  (None, 128, 85, 64)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 85, 64)       36928
#
#  conv2d_2 (Conv2D)           (None, 128, 85, 128)      73856
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 28, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 64, 28, 256)       295168
#
#  conv2d_4 (Conv2D)           (None, 64, 28, 128)       295040
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 14, 128)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 32, 14, 128)       147584
#
#  conv2d_6 (Conv2D)           (None, 32, 14, 128)       147584
#
#  reshape (Reshape)           (None, 448, 128)          0
#
#  bidirectional (Bidirectiona  (None, 448, 1024)        2625536
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 448, 512)         2623488
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 256)              656384
#  nal)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 100)               25700
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 6,934,367
# Trainable params: 6,934,361
# Non-trainable params: 6
# _________________________________________________________________
# Epoch 1/200
# 90/90 - 21s - loss: 1.1014 - accuracy: 0.3139 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4885 - val_loss: 1.0964 - val_accuracy: 0.3889 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5840 - 21s/epoch - 230ms/step
# Epoch 2/200
# 90/90 - 13s - loss: 1.0818 - accuracy: 0.4125 - precision: 0.4300 - recall: 0.0597 - auc: 0.5766 - val_loss: 1.0606 - val_accuracy: 0.4889 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6703 - 13s/epoch - 150ms/step
# Epoch 3/200
# 90/90 - 14s - loss: 1.0416 - accuracy: 0.4264 - precision: 0.5283 - recall: 0.1167 - auc: 0.6390 - val_loss: 1.0179 - val_accuracy: 0.5333 - val_precision: 0.7143 - val_recall: 0.1111 - val_auc: 0.7081 - 14s/epoch - 151ms/step
# Epoch 4/200
# 90/90 - 14s - loss: 1.0371 - accuracy: 0.4889 - precision: 0.5215 - recall: 0.1347 - auc: 0.6562 - val_loss: 0.9605 - val_accuracy: 0.5556 - val_precision: 0.7059 - val_recall: 0.1333 - val_auc: 0.7493 - 14s/epoch - 154ms/step
# Epoch 5/200
# 90/90 - 14s - loss: 0.9685 - accuracy: 0.5194 - precision: 0.6026 - recall: 0.2569 - auc: 0.7170 - val_loss: 0.8553 - val_accuracy: 0.6111 - val_precision: 0.7111 - val_recall: 0.3556 - val_auc: 0.8125 - 14s/epoch - 159ms/step
# Epoch 6/200
# 90/90 - 14s - loss: 0.9149 - accuracy: 0.5569 - precision: 0.6330 - recall: 0.3306 - auc: 0.7549 - val_loss: 0.7794 - val_accuracy: 0.5889 - val_precision: 0.6857 - val_recall: 0.5333 - val_auc: 0.8302 - 14s/epoch - 156ms/step
# Epoch 7/200
# 90/90 - 14s - loss: 0.8583 - accuracy: 0.5847 - precision: 0.6569 - recall: 0.4042 - auc: 0.7857 - val_loss: 0.7376 - val_accuracy: 0.6333 - val_precision: 0.6849 - val_recall: 0.5556 - val_auc: 0.8375 - 14s/epoch - 154ms/step
# Epoch 8/200
# 90/90 - 14s - loss: 0.7918 - accuracy: 0.6139 - precision: 0.6742 - recall: 0.4972 - auc: 0.8165 - val_loss: 0.8309 - val_accuracy: 0.6333 - val_precision: 0.6833 - val_recall: 0.4556 - val_auc: 0.8081 - 14s/epoch - 155ms/step
# Epoch 9/200
# 90/90 - 15s - loss: 0.7116 - accuracy: 0.6722 - precision: 0.7257 - recall: 0.5403 - auc: 0.8601 - val_loss: 0.6608 - val_accuracy: 0.6667 - val_precision: 0.7024 - val_recall: 0.6556 - val_auc: 0.8773 - 15s/epoch - 162ms/step
# Epoch 10/200
# 90/90 - 14s - loss: 0.7315 - accuracy: 0.6597 - precision: 0.7145 - recall: 0.5597 - auc: 0.8486 - val_loss: 0.6407 - val_accuracy: 0.7111 - val_precision: 0.7195 - val_recall: 0.6556 - val_auc: 0.8802 - 14s/epoch - 160ms/step
# Epoch 11/200
# 90/90 - 14s - loss: 0.6751 - accuracy: 0.6875 - precision: 0.7460 - recall: 0.5875 - auc: 0.8694 - val_loss: 0.6461 - val_accuracy: 0.6889 - val_precision: 0.7467 - val_recall: 0.6222 - val_auc: 0.8824 - 14s/epoch - 155ms/step
# Epoch 12/200
# 90/90 - 14s - loss: 0.6376 - accuracy: 0.7194 - precision: 0.7479 - recall: 0.6264 - auc: 0.8838 - val_loss: 0.5807 - val_accuracy: 0.7000 - val_precision: 0.7160 - val_recall: 0.6444 - val_auc: 0.8954 - 14s/epoch - 157ms/step
# Epoch 13/200
# 90/90 - 14s - loss: 0.6009 - accuracy: 0.7264 - precision: 0.7674 - recall: 0.6417 - auc: 0.8972 - val_loss: 0.6894 - val_accuracy: 0.6556 - val_precision: 0.6667 - val_recall: 0.6444 - val_auc: 0.8661 - 14s/epoch - 152ms/step
# Epoch 14/200
# 90/90 - 14s - loss: 0.6026 - accuracy: 0.7278 - precision: 0.7566 - recall: 0.6736 - auc: 0.8981 - val_loss: 0.5449 - val_accuracy: 0.7667 - val_precision: 0.7949 - val_recall: 0.6889 - val_auc: 0.9176 - 14s/epoch - 153ms/step
# Epoch 15/200
# 90/90 - 14s - loss: 0.6959 - accuracy: 0.7194 - precision: 0.7528 - recall: 0.6514 - auc: 0.8806 - val_loss: 0.5351 - val_accuracy: 0.7556 - val_precision: 0.7805 - val_recall: 0.7111 - val_auc: 0.9097 - 14s/epoch - 153ms/step
# Epoch 16/200
# 90/90 - 14s - loss: 0.5765 - accuracy: 0.7431 - precision: 0.7721 - recall: 0.6917 - auc: 0.9056 - val_loss: 0.5063 - val_accuracy: 0.7556 - val_precision: 0.7831 - val_recall: 0.7222 - val_auc: 0.9280 - 14s/epoch - 157ms/step
# Epoch 17/200
# 90/90 - 14s - loss: 0.5260 - accuracy: 0.7653 - precision: 0.7910 - recall: 0.7097 - auc: 0.9208 - val_loss: 0.5802 - val_accuracy: 0.7000 - val_precision: 0.6966 - val_recall: 0.6889 - val_auc: 0.8989 - 14s/epoch - 151ms/step
# Epoch 18/200
# 90/90 - 14s - loss: 0.5541 - accuracy: 0.7486 - precision: 0.7682 - recall: 0.6903 - auc: 0.9121 - val_loss: 0.4798 - val_accuracy: 0.8000 - val_precision: 0.8250 - val_recall: 0.7333 - val_auc: 0.9437 - 14s/epoch - 151ms/step
# Epoch 19/200
# 90/90 - 14s - loss: 0.5377 - accuracy: 0.7667 - precision: 0.7930 - recall: 0.7236 - auc: 0.9194 - val_loss: 0.5257 - val_accuracy: 0.7556 - val_precision: 0.7711 - val_recall: 0.7111 - val_auc: 0.9176 - 14s/epoch - 150ms/step
# Epoch 20/200
# 90/90 - 14s - loss: 0.4794 - accuracy: 0.7986 - precision: 0.8171 - recall: 0.7569 - auc: 0.9346 - val_loss: 0.5031 - val_accuracy: 0.7889 - val_precision: 0.8000 - val_recall: 0.7556 - val_auc: 0.9250 - 14s/epoch - 152ms/step
# Epoch 21/200
# 90/90 - 14s - loss: 0.4765 - accuracy: 0.7972 - precision: 0.8117 - recall: 0.7722 - auc: 0.9358 - val_loss: 0.5939 - val_accuracy: 0.7111 - val_precision: 0.7326 - val_recall: 0.7000 - val_auc: 0.9025 - 14s/epoch - 151ms/step
# Epoch 22/200
# 90/90 - 14s - loss: 0.4948 - accuracy: 0.7986 - precision: 0.8180 - recall: 0.7681 - auc: 0.9331 - val_loss: 0.5085 - val_accuracy: 0.7222 - val_precision: 0.7381 - val_recall: 0.6889 - val_auc: 0.9260 - 14s/epoch - 151ms/step
# Epoch 23/200
# 90/90 - 14s - loss: 0.4205 - accuracy: 0.8222 - precision: 0.8352 - recall: 0.8097 - auc: 0.9493 - val_loss: 0.3886 - val_accuracy: 0.8000 - val_precision: 0.8235 - val_recall: 0.7778 - val_auc: 0.9587 - 14s/epoch - 152ms/step
# Epoch 24/200
# 90/90 - 13s - loss: 0.4159 - accuracy: 0.8278 - precision: 0.8426 - recall: 0.7958 - auc: 0.9512 - val_loss: 0.4093 - val_accuracy: 0.8333 - val_precision: 0.8488 - val_recall: 0.8111 - val_auc: 0.9530 - 13s/epoch - 149ms/step
# Epoch 25/200
# 90/90 - 13s - loss: 0.3661 - accuracy: 0.8514 - precision: 0.8672 - recall: 0.8347 - auc: 0.9630 - val_loss: 0.5067 - val_accuracy: 0.7889 - val_precision: 0.7865 - val_recall: 0.7778 - val_auc: 0.9351 - 13s/epoch - 149ms/step
# Epoch 26/200
# 90/90 - 14s - loss: 0.3418 - accuracy: 0.8694 - precision: 0.8858 - recall: 0.8514 - auc: 0.9673 - val_loss: 0.4498 - val_accuracy: 0.8333 - val_precision: 0.8409 - val_recall: 0.8222 - val_auc: 0.9463 - 14s/epoch - 150ms/step
# Epoch 27/200
# 90/90 - 14s - loss: 0.2850 - accuracy: 0.8931 - precision: 0.9004 - recall: 0.8792 - auc: 0.9774 - val_loss: 0.4117 - val_accuracy: 0.8556 - val_precision: 0.8636 - val_recall: 0.8444 - val_auc: 0.9552 - 14s/epoch - 151ms/step
# Epoch 28/200
# 90/90 - 14s - loss: 0.3239 - accuracy: 0.8681 - precision: 0.8793 - recall: 0.8500 - auc: 0.9703 - val_loss: 0.3669 - val_accuracy: 0.8667 - val_precision: 0.8652 - val_recall: 0.8556 - val_auc: 0.9629 - 14s/epoch - 155ms/step
# Epoch 29/200
# 90/90 - 14s - loss: 0.3103 - accuracy: 0.8958 - precision: 0.9078 - recall: 0.8750 - auc: 0.9734 - val_loss: 0.3722 - val_accuracy: 0.8333 - val_precision: 0.8427 - val_recall: 0.8333 - val_auc: 0.9648 - 14s/epoch - 153ms/step
# Epoch 30/200
# 90/90 - 14s - loss: 0.2679 - accuracy: 0.8931 - precision: 0.8980 - recall: 0.8806 - auc: 0.9796 - val_loss: 0.3253 - val_accuracy: 0.8889 - val_precision: 0.9176 - val_recall: 0.8667 - val_auc: 0.9723 - 14s/epoch - 153ms/step
# Epoch 31/200
# 90/90 - 13s - loss: 0.2101 - accuracy: 0.9361 - precision: 0.9382 - recall: 0.9278 - auc: 0.9867 - val_loss: 0.3891 - val_accuracy: 0.8556 - val_precision: 0.8539 - val_recall: 0.8444 - val_auc: 0.9680 - 13s/epoch - 150ms/step
# Epoch 32/200
# 90/90 - 13s - loss: 0.2065 - accuracy: 0.9319 - precision: 0.9392 - recall: 0.9222 - auc: 0.9877 - val_loss: 0.3717 - val_accuracy: 0.8556 - val_precision: 0.8636 - val_recall: 0.8444 - val_auc: 0.9669 - 13s/epoch - 149ms/step
# Epoch 33/200
# 90/90 - 13s - loss: 0.1489 - accuracy: 0.9611 - precision: 0.9609 - recall: 0.9569 - auc: 0.9916 - val_loss: 0.3758 - val_accuracy: 0.8444 - val_precision: 0.8444 - val_recall: 0.8444 - val_auc: 0.9679 - 13s/epoch - 149ms/step
# Epoch 34/200
# 90/90 - 13s - loss: 0.1732 - accuracy: 0.9458 - precision: 0.9483 - recall: 0.9417 - auc: 0.9900 - val_loss: 0.4089 - val_accuracy: 0.8444 - val_precision: 0.8444 - val_recall: 0.8444 - val_auc: 0.9644 - 13s/epoch - 148ms/step
# Epoch 35/200
# 90/90 - 14s - loss: 0.1529 - accuracy: 0.9583 - precision: 0.9595 - recall: 0.9542 - auc: 0.9918 - val_loss: 0.3439 - val_accuracy: 0.9000 - val_precision: 0.9101 - val_recall: 0.9000 - val_auc: 0.9714 - 14s/epoch - 151ms/step
# Model saved as cnn_lstm_final.h5
# 12/12 - 1s - loss: 0.4070 - accuracy: 0.8556 - precision: 0.8652 - recall: 0.8556 - auc: 0.9573 - 727ms/epoch - 61ms/step
#
# Test Accuracy: 85.56%
# Test Loss: 0.4070
# Precision: 0.8652
# Recall: 0.8556
# AUC: 0.9573
# 12/12 [==============================] - 1s 53ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.97      0.93      0.95        30
#          low       0.74      0.93      0.82        30
#     moderate       0.91      0.70      0.79        30
#
#     accuracy                           0.86        90
#    macro avg       0.87      0.86      0.86        90
# weighted avg       0.87      0.86      0.86        90
#
# Macro-Averaged F1 Score: 0.8550

# %%
# Bidirectional LSTM
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, BatchNormalization,
                                     Reshape, LSTM, Dropout, Dense)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, f1_score
from sklearn.preprocessing import label_binarize
from tensorflow.keras.layers import Bidirectional


# ============ Parameters ============
IMG_SIZE = 256
BATCH_SIZE = 8
EPOCHS = 200
NUM_CLASSES = 3  # low, moderate, high

# ============ Data Loaders ============
train_gen = ImageDataGenerator(rescale=1./255)
val_gen = ImageDataGenerator(rescale=1./255)
test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    'train',  # folder with subfolders: low, moderate, high
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_data = val_gen.flow_from_directory(
    'validation',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_data = test_gen.flow_from_directory(
    'test',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  # Important for matching predictions to labels
)

# ============ Model Architecture (CNN-LSTM) ============
input_layer = Input(shape=(IMG_SIZE, IMG_SIZE, 3))

# CNN Feature Extractor
x = BatchNormalization()(input_layer)
x = Conv2D(64, (5, 7), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 3))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 3))(x)

x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)

# LSTM
x = Reshape((x.shape[1] * x.shape[2], x.shape[3]))(x)

# LSTM layers
x = Bidirectional(LSTM(512, return_sequences=True))(x)
x = Bidirectional(LSTM(256, return_sequences=True))(x)
x = Bidirectional(LSTM(128))(x)

# Dense Layers
x = Dropout(0.25)(x)
x = Dense(100, activation='relu')(x)
x = Dropout(0.75)(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)

# Build and Compile Model
model = Model(inputs=input_layer, outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss='categorical_crossentropy',
              metrics=[
                  'accuracy',
                  tf.keras.metrics.Precision(name='precision'),
                  tf.keras.metrics.Recall(name='recall'),
                  tf.keras.metrics.AUC(name='auc')
              ])
model.summary()

# ============ Training ============
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('cnn_lstm_best.h5', save_best_only=True)
]

model.fit(train_data,
          validation_data=val_data,
          epochs=EPOCHS,
          callbacks=callbacks,
          verbose=2)

# Save Final Model
model.save("cnn_Bilstm_final2405.h5")
print("cnn_Bilstm_final2405.h5")
